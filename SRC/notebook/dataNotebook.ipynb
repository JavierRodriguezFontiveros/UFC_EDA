# %%
import pandas as pd

# %% [markdown]
# <p align="center">
#   <img src="./UFC.jpg" alt="Texto alternativo" />
# </p>

# %% [markdown]
# <h1 align="center">Análisis exploratorio de datos de la UFC</h1>
# &nbsp;

# %% [markdown]
# Este **EDA** se centra principalmente en abordar las hipótesis más comúnmente planteadas por los **"opinólogos de bar"** 🍻 en el mundo de los deportes de contacto 🥋.
#
# Ha sido realizada a través de la exploración de 2 **DATASETS** 📊 repletos de estadísticas detalladas y específicas 📈.
#
# &nbsp;
#
# Se ha buscado analizar estas suposiciones para llegar a **conclusiones fundamentadas** 🔍, teniendo un enfoque en patrones de rendimiento y tendencias 📈.
#
# Este análisis pretende **ofrecer una perspectiva** más clara sobre el **éxito**🏆 de los luchadores.
#
# &nbsp;

# %% [markdown]
# ### A lo largo del análisis, se han formulado varias **hipótesis** que guiarán nuestra investigación:
#
#
#
# ---
#
# #### 1. **Relación entre la guardia y el Éxito en ambos generos** 🤼
#    - **Hipótesis**: Los luchadores que utilizan una **guardia ortodoxa** obtienen un **mayor número de victorias**.
#
# &nbsp;
#
# ---
#
# #### 2. **Defensiva de Takedowns y Éxito en la Carrera** 🥋
#    - **Hipótesis**: Los luchadores con una **alta defensa de derribos** tienen un **porcentaje más alto de victorias** en su carrera.
#
# &nbsp;
#
# ---
#
# #### 3. **Rendimiento por Género** 🚺🤼‍♂️
#    - **Hipótesis**: Las **peleadoras femeninas** tienen un rendimiento **mayor** en términos de **victorias** y **métodos de finalización** en comparación con los **peleadores masculinos**.
#
# &nbsp;
#
# ---
#
# #### 4. **Diferencia de Edades** 👵👦
#    - **Hipótesis**: Un **peleador más joven** tiene más probabilidades de ganar contra un **oponente mayor**.
#
# &nbsp;
#
# ---
#
# #### 5. **Knockouts en diferentes Divisiónes** 🥊
#    - **Hipótesis**: En la **división de pesos pesados**, hay **más knockouts** pero **menos cantidad de golpes** lanzados en comparación con otras categorías.
#
# &nbsp;
#
# ---
#
# #### 6. **EXTRA** 📏🏆
# - **Hipótesis**: Los luchadores más **altos** **SIEMPRE** ganarán a los más **bajos**.
#
#
# &nbsp;

# %%
#Estadísticas de los peleadores
estadisticas_peleador = pd.read_csv("./estadísticas_peleador.csv")
fuente_1 = "https://www.kaggle.com/datasets/maksbasher/ufc-complete-dataset-all-events-1996-2024/data"
estadisticas_peleador.head(11)
# Out:
#                  name  wins  losses  height  weight   reach    stance   age  \
# 0        Amanda Ribas  12.0     5.0  160.02   56.70  167.64  Orthodox  30.0
# 1      Rose Namajunas  13.0     6.0  165.10   56.70  165.10  Orthodox  31.0
# 2       Karl Williams  10.0     1.0  190.50  106.59  200.66  Orthodox  34.0
# 3         Justin Tafa   7.0     4.0  182.88  119.75  187.96  Southpaw  30.0
# 4    Edmen Shahbazyan  13.0     4.0  187.96   83.91  190.50  Orthodox  26.0
# 5           AJ Dobson   7.0     3.0  185.42   83.91  193.04  Orthodox  32.0
# 6      Payton Talbott   8.0     0.0  177.80   61.23  177.80    Switch  25.0
# 7     Cameron Saaiman   9.0     2.0  172.72   61.23  170.18  Southpaw  23.0
# 8   Billy Quarantillo  18.0     6.0  177.80   65.77  177.80  Orthodox  35.0
# 9       Youssef Zalal  14.0     5.0  177.80   65.77  182.88    Switch  27.0
# 10   Fernando Padilla  16.0     5.0  185.42   65.77  193.04  Orthodox  27.0
#
# ...

# %% [markdown]
# # Número total de peleadores 🥊 y métricas 📒
#
# - **Peleadores**: 2479
#
# - **Métricas**: 16
#
# &nbsp;

# %%
#Estadísticas de los peleadores
enfrentamientos = pd.read_csv("./Enfrentamientos.csv")
fuente_2 = "https://www.kaggle.com/datasets/maksbasher/ufc-complete-dataset-all-events-1996-2024/data"
enfrentamientos.head(11)
# Out:
#                                    event       date                location  \
# 0   UFC Fight Night: Ribas vs. Namajunas  3/23/2024  Las Vegas, Nevada, USA
# 1   UFC Fight Night: Ribas vs. Namajunas  3/23/2024  Las Vegas, Nevada, USA
# 2   UFC Fight Night: Ribas vs. Namajunas  3/23/2024  Las Vegas, Nevada, USA
# 3   UFC Fight Night: Ribas vs. Namajunas  3/23/2024  Las Vegas, Nevada, USA
# 4   UFC Fight Night: Ribas vs. Namajunas  3/23/2024  Las Vegas, Nevada, USA
# 5   UFC Fight Night: Ribas vs. Namajunas  3/23/2024  Las Vegas, Nevada, USA
# 6   UFC Fight Night: Ribas vs. Namajunas  3/23/2024  Las Vegas, Nevada, USA
# 7   UFC Fight Night: Ribas vs. Namajunas  3/23/2024  Las Vegas, Nevada, USA
# 8   UFC Fight Night: Ribas vs. Namajunas  3/23/2024  Las Vegas, Nevada, USA
# 9   UFC Fight Night: Ribas vs. Namajunas  3/23/2024  Las Vegas, Nevada, USA
# 10  UFC Fight Night: Ribas vs. Namajunas  3/23/2024  Las Vegas, Nevada, USA
#
# ...

# %% [markdown]
# # Número total de enfrentamientos  🤼‍♂️  y métricas 📒
#
# - **Enfrentamientos**: 7582
#
# - **Métricas**: 19
